# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import warnings
import scipy.stats as stats
warnings.filterwarnings("ignore")

# %%
cutlets = pd.read_csv("C:/Users/tusha/Downloads/Cutlets.csv")
cutlets.head(5)
# Out:
#    Unit A  Unit B
# 0  6.8090  6.7703
# 1  6.4376  7.5093
# 2  6.9157  6.7300
# 3  7.3012  6.7878
# 4  7.4488  7.1522

# %%
cutlets.describe()
# Out:
#           Unit A     Unit B
# count  35.000000  35.000000
# mean    7.019091   6.964297
# std     0.288408   0.343401
# min     6.437600   6.038000
# 25%     6.831500   6.753600
# 50%     6.943800   6.939900
# 75%     7.280550   7.195000
# max     7.516900   7.545900

# %%
cutlets.isnull().sum()
# Out:
# Unit A    0
# Unit B    0
# dtype: int64

# %%
cutlets[cutlets.duplicated()].shape
# Out:
# (0, 2)

# %%
cutlets[cutlets.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Unit A, Unit B]
# Index: []

# %%
cutlets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Unit A  35 non-null     float64
#  1   Unit B  35 non-null     float64
# dtypes: float64(2)
# memory usage: 692.0 bytes

# %% [markdown]
# ### Ploting the Data

# %%
plt.subplots(figsize = (9,6))
plt.subplot(121)
plt.boxplot(cutlets['Unit A'])
plt.title('Unit A')
plt.subplot(122)
plt.boxplot(cutlets['Unit B'])
plt.title('Unit B')
plt.show()

# %%
plt.subplots(figsize=(9,6))
plt.subplot(121)
plt.hist(cutlets['Unit A'],bins = 15)
plt.title('Unit A')
plt.subplot(122)
plt.hist(cutlets['Unit B'],bins = 15)
plt.title('Unit B')
plt.show()

# %%
plt.figure(figsize = (8,6))
labels = ['Unit A', 'Unit B']
sns.distplot(cutlets['Unit A'], kde = True)
sns.distplot(cutlets['Unit B'],hist = True)
plt.legend(labels)

# %% [markdown]
# ### Plotting Q-Q plot to check whether the distribution follows normal distribution or not

# %%
sm.qqplot(cutlets['Unit A'],line = 'q')
plt.title('Unit A')
sm.qqplot(cutlets['Unit B'],line = 'q')
plt.title('Unit B')
plt.show()

# %% [markdown]
# ### Compare Evidences with Hypothesis using t-statistics

# %%
statistic , p_value = stats.ttest_ind(cutlets['Unit A'],cutlets['Unit B'],alternative='two-sided')
print('p_value =',p_value)
# Out:
# p_value = 0.4722394724599501

# %% [markdown]
# ### As p-value != alpha we failed to reject Null Hypothesis because of lack of evidence

# %% [markdown]
# ### It's important to note that failing to reject the null hypothesis does not necessarily mean that there is no difference between the two units. It simply means that the evidence in the data is not strong enough to claim a significant difference. There could still be a difference, but the data we have collected is not conclusive enough to support that assertion.

# %% [markdown]
# ### Q2) A F&B manager wants to determine whether there is any significant difference in the diameter of the cutlet between two units. A randomly selected sample of cutlets was collected from both units and measured? Analyze the data and draw inferences at 5% significance level. Please state the assumptions and tests that you carried out to check validity of the assumptions

# %% [markdown]
# ### We are going to conduct a ANOVA TEST on 4 Independent samples with Numerical Data
# ### We need to check wether the mean of any of these samples are different or same?
# ### Step 1
#  ### Null Hypothesis: Mu1 = Mu2 = Mu3 = Mu4
# ### Alternative Hypothesis: Atleast one of them is different
# ### Step 2
# ### Decide a cut-off value
# ### Significance 5%
# ### alpha = 0.05
# ### Step 3
# ### Collect evidence
# ### Importing Files

# %%
labtat = pd.read_csv("C:/Users/tusha/Downloads/LabTAT.csv")
labtat.head(5)
# Out:
#    Laboratory 1  Laboratory 2  Laboratory 3  Laboratory 4
# 0        185.35        165.53        176.70        166.13
# 1        170.49        185.91        198.45        160.79
# 2        192.77        194.92        201.23        185.18
# 3        177.33        183.00        199.61        176.42
# 4        193.41        169.57        204.63        152.60

# %%
labtat.describe()
# Out:
#        Laboratory 1  Laboratory 2  Laboratory 3  Laboratory 4
# count    120.000000    120.000000    120.000000     120.00000
# mean     178.361583    178.902917    199.913250     163.68275
# std       13.173594     14.957114     16.539033      15.08508
# min      138.300000    140.550000    159.690000     124.06000
# 25%      170.335000    168.025000    188.232500     154.05000
# 50%      178.530000    178.870000    199.805000     164.42500
# 75%      186.535000    189.112500    211.332500     172.88250
# max      216.390000    217.860000    238.700000     205.18000

# %%
labtat.isna().sum()
# Out:
# Laboratory 1    0
# Laboratory 2    0
# Laboratory 3    0
# Laboratory 4    0
# dtype: int64

# %%
labtat[labtat.duplicated()].shape
# Out:
# (0, 4)

# %%
labtat[labtat.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Laboratory 1, Laboratory 2, Laboratory 3, Laboratory 4]
# Index: []

# %% [markdown]
# ### Plotting the data

# %%
plt.subplots(figsize =(16,9))
plt.subplot(221)
plt.boxplot(labtat['Laboratory 1'])
plt.title('Laboratory 1')
plt.subplot(222)
plt.boxplot(labtat['Laboratory 2'])
plt.title('Laboratory 2')
plt.subplot(223)
plt.boxplot(labtat['Laboratory 3'])
plt.title('Laboratory 3')
plt.subplot(224)
plt.boxplot(labtat['Laboratory 4'])
plt.title('Laboratory 4')
plt.show()

# %%
plt.subplots(figsize=(9,6))
plt.subplot(221)
plt.hist(labtat['Laboratory 1'])
plt.title('Laboratory 1')
plt.subplot(222)
plt.hist(labtat['Laboratory 2'])
plt.title('Laboratory 2')
plt.subplot(223)
plt.hist(labtat['Laboratory 3'])
plt.title('Laboratory 3')
plt.subplot(224)
plt.hist(labtat['Laboratory 4'])
plt.title('Laboratory 4')
plt.show()

# %%
plt.figure(figsize=(8,6))
labels = ['Lab 1','Lab 2','Lab 3','Lab 4']
sns.distplot(labtat['Laboratory 1'],kde = True)
sns.distplot(labtat['Laboratory 2'],hist = True)
sns.distplot(labtat['Laboratory 3'],hist = True)
sns.distplot(labtat['Laboratory 4'],hist = True)
plt.legend(labels)

# %%
from PIL import ImageGrab
ImageGrab.grabclipboard()

# %% [markdown]
# ### Plotting a Q-Q plot to check whether the distribution follows a Normal Distribution or not

# %%
sm.qqplot(labtat['Laboratory 1'],line = 'q')
plt.title('Laboratory 1')
sm.qqplot(labtat['Laboratory 2'],line='q')
plt.title('Laboratory 2')
sm.qqplot(labtat['Laboratory 3'],line='q')
plt.title('Laboratory 3')
sm.qqplot(labtat['Laboratory 4'],line='q')
plt.title('Laboratory 4')
plt.show()

# %% [markdown]
# #### Step 4
# ### Compare Evidences with Hypothesis using t-statistic

# %%
test_statistic, p_value = stats.f_oneway(labtat.iloc[:,0],labtat.iloc[:,1],labtat.iloc[:,2],labtat.iloc[:,3])
print('p_value =',p_value)
# Out:
# p_value = 2.1156708949992414e-57

# %% [markdown]
# ### interpreting p_value

# %%
alpha = 0.05
print('Significance = {:.3f},p={:.3f}'.format(alpha,p_value))
if p_value <= alpha:
    print('We reject the Null Hypothesis')
else:
    print('We fail to reject Null Hypothesis')
# Out:
# Significance = 0.050,p=0.000
# We reject the Null Hypothesis

# %% [markdown]
# ### Since the p-value (0.000) is less than the significance level (0.050), we reject the null hypothesis, we would conclude that there is evidence to suggest a significant difference between the groups being compared.

# %% [markdown]
# ### Q3) Sales of products in four different regions is tabulated for males and females. Find if male-female buyer rations are similar across regions.
# ### We are going to conduct a Test of Independence using Chi-Square test with Contigency table
# ### We need to check whether the proportion of any of these samples are different or the same?
# ## Step 1
# ### Null Hypothesis: There is no association or dependency between the gender based buyer rations across regions
# ### Alternative Hypothesis: There is significant association or dependency between the gender based buyer rations across region
# ## Step 2
# ### Decide a cut-off value
# ### Significance 5%
# ### alpha = 0.05
# ## Step 3
# ### Importing Files

# %%
buyer = pd.read_csv("C:/Users/tusha/Downloads/BuyerRatio.csv")
buyer.head(5)
# Out:
#   Observed Values  East  West  North  South
# 0           Males    50   142    131     70
# 1         Females   435  1523   1356    750

# %%
table =[[50,142,131,70],[435,1523,1356,750]]

# %% [markdown]
# ### Applying Chi-Square contigency table to convert observed value into expected value

# %%
stat, p, dof, exp = stats.chi2_contingency(table) 
print(stat,"\n", p,"\n", dof,"\n", exp)
# Out:
# 1.595945538661058
#  0.6603094907091882
#  3
#  [[  42.76531299  146.81287862  131.11756787   72.30424052]
#  [ 442.23468701 1518.18712138 1355.88243213  747.69575948]]

# %%
observed = np.array([50,142,131,70,435,1523,1356,750])
expected = np.array([42.76531299,146.81287862,131.11756787,72.30424052,442.23468701,1518.18712138,1355.88243213,747.69575948])

# %% [markdown]
# ## Step 4
# ### Comparing Evidence with Hypothesis

# %%
statistic, p_value = stats.chisquare(observed,expected,ddof=3)
print("Statistics = ",statistic,"\n",'P_Value = ', p_value)
# Out:
# Statistics =  1.5959455390914483
#  P_Value =  0.8095206646905712

# %%
print('Significance = {:.3f},p={:.3f}'.format(alpha,p_value))
# Out:
# Significance = 0.050,p=0.810

# %% [markdown]
# ### Interpreting p_value

# %%
alpha = 0.05
print('Significance = {:.3f},p={:.3f}'.format(alpha,p_value))
if p_value<=alpha:
    print('We reject Null Hypothesis')
else:
    print('We fail to reject Null Hypothesis')
# Out:
# Significance = 0.050,p=0.810
# We fail to reject Null Hypothesis

# %% [markdown]
# ### We fail to reject Null Hypothesis because of lack evidence. Therefore, there is no association or dependency between male-female buyers rations and are similar across regions. Hence, Independent samples
